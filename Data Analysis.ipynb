# %%
import pandas as pd

# %%
data = pd.read_csv("data/train.csv")

# %%
data.sample(10)
# Out:
#                                                    text  label language
# 8973                                    @user 鎖起來處置？ 哈哈   2.60  Chinese
# 1209                                   @user Ohhh got u   1.00  English
# 6164  Valanghe, cessato stato di attenzione su Dolom...   1.00  Italian
# 4785  @user @capuanogio L’ho criticato spesso…stavol...   1.40  Italian
# 8927  @user 凯文·布拉迪发表声明，称美中达成贸易协议“对美国工人和公司来说是历史性的一天“。...   1.00  Chinese
# 2015      @user @user Habría que charlar diría yo. Jeje   2.25  Spanish
# 7920  我已经懒到来推了 叫入🚪也累了 基本上是vx了 想进的直接口令和vx号 我看到会领了再加的 ...   3.00  Chinese
# 8901  ［ 與大屌網紅的真實自拍3-3 ］ 其實很多人知道影片主角了😂 就是認識蠻久的濕濕@happ...   2.80  Chinese
# 9029                                @user 我射了很多洨給這個男優哈哈   4.80  Chinese
# 2760    este nudo en la garganta que no se va con nada😪   3.75  Spanish

# %%
data.label.describe()
# Out:
# count    9491.000000
# mean        2.093782
# std         0.903512
# min         1.000000
# 25%         1.400000
# 50%         2.000000
# 75%         2.666667
# max         5.000000
# Name: label, dtype: float64

# %%
data.groupby('language').count()
# Out:
#             text  label
# language
# Chinese     1596   1596
# English     1587   1587
# French      1588   1588
# Italian     1532   1532
# Portuguese  1596   1596
# Spanish     1592   1592

# %%
data.groupby(["label", "language"]).describe()
# Out:
#                   text         \
#                  count unique
# label language
# 1.0   Chinese      142    142
#       English      343    343
#       French       238    238
#       Italian      281    281
#       Portuguese   148    142
# ...                ...    ...
# 5.0   English        8      8
#       French         1      1
#       Italian        2      2
#       Portuguese     1      1
#       Spanish        2      2
#
#
#                                                                 top freq
# label language
# 1.0   Chinese     尋找所有人的匿名問題！ Nick沒有任何問題！ Nick山第一個令人難忘的答案可能是您的問題...    1
#       English                                  Bees vs. Wasps. http    1
#       French                     Allez maintenant le #SpanishGP #F1    1
#       Italian     @user Il primo esempio che le ho fatto è stata...    1
#       Portuguese  seu perfil foi visto por 6 pessoas nas últimas...    5
# ...                                                             ...  ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9491 entries, 0 to 9490
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   text      9491 non-null   object
#  1   label     9491 non-null   float64
#  2   language  9491 non-null   object
# dtypes: float64(1), object(2)
# memory usage: 222.6+ KB
